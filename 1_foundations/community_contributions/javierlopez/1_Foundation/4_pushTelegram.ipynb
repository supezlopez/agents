# %%
from dotenv import load_dotenv
import json
import os
import requests
import asyncio

# %%
load_dotenv(override=True)
# Out:
# True

# %%
telegramid_chat = os.getenv("TELEGRAMCHATID")

# %%
def pushToTelegram(message):

    if telegramid_chat:
        print ('Chat found and starts with ' + telegramid_chat)
    else:
        print ('Chat NOT found')

    telegram_token = os.getenv("TELEGRAMTOKEN")


    if telegram_token:
        print ('Chat found and starts with ' + telegram_token)
    else:
        print ('Telegram Token NOT found')

    url = f"https://api.telegram.org/bot{telegram_token}/sendMessage"
    print (url)
    payload = {
        "chat_id": telegramid_chat,
        "text": message,
        "parse_mode": "Markdown"  # o "HTML"
    }
    response = requests.post(url, json=payload)
    print (response)

# %%
response = requests.post(
    url="https://api.telegram.org/bot8605502153:AAH96A0U6utqJaq12lCDi0xAa4NA8rfu4BM/sendMessage", 
chat_id="CiscMachineBot", 
text="sample"
)

print (response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = requests.post(
#       2     url="https://api.telegram.org/bot8605502153:AAH96A0U6utqJaq12lCDi0xAa4NA8rfu4BM/sendMessage",
#       3 chat_id="t.me/CiscMachineBot",
#       4 text="sample"
#       5 )
#       7 print (response)
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# TypeError: Session.request() got an unexpected keyword argument 'chat_id'

# %%
pushToTelegram("hola canalla")
# Out:
# Chat found and starts with 8605502153:AAH96A0U6utqJaq12lCDi0xAa4NA8rfu4BM
# Chat found and starts with t.me/CiscMachineBot
# https://api.telegram.org/bott.me/CiscMachineBot/sendMessage
# <Response [404]>
